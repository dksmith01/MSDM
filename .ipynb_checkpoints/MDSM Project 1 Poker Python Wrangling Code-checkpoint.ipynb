# %% [markdown]
# # Miami Data Science Meetup
# # Project 1: Poker Data
# ### October 4, 2015
#
# This set of functions takes multiple Texas Hold-'Em hand files downloaded from the [University of Alberta Computer Poker Research group's website](http://poker.cs.ualberta.ca/IRCdata/) to the local machine, parses them into a list of Python dictionaries, and outputs a JSON file called cprg_hands.json.
#
# This JSON file can then be uploaded to MongoDB (assuming you have an instance running) with the following command from the Terminal command prompt (on Mac; don't know how to do it on a PC):
# >mongoimport --host 127.0.0.1:27017 --db <db name> --collection <collection name> --file cprg_hands.json

# %%
'''
INPUT: 
The loop_tgz function below looks in the specified environment directory for all available files with a filename in 
the format <game_type>.MMMMYY.tgz. This is a compressed "zip" file type that the loop_tgz function extracts into 
uncompressed, readable files.

Each .tgz file extracts a "file group" of the following structure:
./<game_type>/MMMMYYY/hdb
./<game_type>/MMMMYYY/hroster
./<game_type>/MMMMYYY/pdb/pdb.player1 <- where "player1" is one player's username
./<game_type>/MMMMYYY/pdb/pdb.player2
./<game_type>/MMMMYYY/pdb/pdb.player3
...
./<game_type>/MMMMYYY/pdb/pdb.playerN

For the hand below, the various files have records that look like the following:
hdb file: 

HAND INFORMATION (in hdb file)
------------------------------
timestamp      hand #     #players/starting potsize
         dealer    #play flop    turn    river  showdn     board
820830094  20  1163  2  2/20    2/40    2/80     2/80     Qc 4s 6s 5d 4d

ROSTER INFORMATION (in hroster file)
------------------------------------
820830094  2 Jak num

PLAYER INFORMATION (in pdb.* files)
-----------------------------------
player             #play prflop    turn         bankroll    winnings
          timestamp    pos   flop       river           action  cards
Jak       820830094  2  1 Bc  kc    kc    k          850   40   80 7c Ac
num       820830094  2  2 Bk  b     b     k         1420   40    0 9h Kh

In English, the database entry says that 2 players are at the table: "Jak" and "num".
Pre-flop, Jak makes a small blind (B) $5, num makes a big blind (B) $10, Jak calls (c), and
num checks (k).  The pot is $20 and we have 2 players.  
The flop comes Qc 4s 6s, Jak checks (k), num bets (b) $10, Jak calls (c). The pot is now $40.  
On the turn, 5d, Jak checks (k), num bets (b) $20, and Jak calls (c). The pot is now $80
On the river, 4d, Jak checks (k), and num checks (k). The pot remains $80.
At the showdown, Jak wins the hand with a pair of board 4's w/ Ace high versus num's board 4's w/ King high. 
As a result, Jak wins the $80 pot. 
Note that we don't know the cards of any players who fold before the showdown.  
Also note that the format does not record exact bet amounts in pot-limit or no-limit, though 
they can often be inferred from the total pot size after each round.


PROCESSING:
All valid hands found in the processed .tgz files are parsed into a list of "hands" dictionaries by running the 
loop_file_groups function, which runs all of the following functions on each file group, one at a time:

- parse_hdb_file: parses the hdb file looking for a hand identifier, betting rounds, and board cards
- parse_hroster_file: parses the hroster file looking for each of the players that played each hand
- loop_pdb_files: loops through all of the pdb files in the pdb folder, identifying each one by the username on the end
    - parse_pdb_files: parses an individual pdb file, to determine what that player did with each hand she played
- append_hands_list_to_json_file: takes a list of all of the valid hands found in the file group, "dumps" them from 
    Python dictionary format to JSON, and appends them to an output file, "cprg_hands.json"


OUTPUT: 

A full element of the Python dictionary list that this code produces looks like this (from the example inputs above):

{'_id': 'holdem_199601_820830094',
 'board': [{'stage': 'flop', 'suit': 'clubs', 'value': 'queen'},
           {'stage': 'flop', 'suit': 'spades', 'value': '4'},
           {'stage': 'flop', 'suit': 'spades', 'value': '6'},
           {'stage': 'turn', 'suit': 'diamonds', 'value': '5'},
           {'stage': 'river', 'suit': 'diamonds', 'value': '4'}],
 'dealer': '20',
 'game_type': 'holdem',
 'hand_num': '1163',
 'num_players': '2',
 'players': {'Jak': {'action': 40,
                     'bankroll': 850,
                     'bet_actions': [{'actions': ['blind bet', 'call'],
                                      'stage': 'pre-flop'},
                                     {'actions': ['check', 'call'],
                                      'stage': 'flop'},
                                     {'actions': ['check', 'call'],
                                      'stage': 'turn'},
                                     {'actions': ['check'],
                                      'stage': 'river'}],
                     'player_cards': [{'suit': 'clubs', 'value': '7'},
                                      {'suit': 'clubs', 'value': 'ace'}],
                     'position': 1,
                     'username': 'Jak',
                     'winnings': 80},
             'num': {'action': 40,
                     'bankroll': 1420,
                     'bet_actions': [{'actions': ['blind bet', 'check'],
                                      'stage': 'pre-flop'},
                                     {'actions': ['bet'], 'stage': 'flop'},
                                     {'actions': ['bet'], 'stage': 'turn'},
                                     {'actions': ['check'],
                                      'stage': 'river'}],
                     'player_cards': [{'suit': 'hearts', 'value': '9'},
                                      {'suit': 'hearts', 'value': 'king'}],
                     'position': 2,
                     'username': 'num',
                     'winnings': 0}},
 'pots': [{'num_players': '2', 'stage': 'flop', 'starting_pot_size': '20'},
          {'num_players': '2', 'stage': 'turn', 'starting_pot_size': '40'},
          {'num_players': '2', 'stage': 'river', 'starting_pot_size': '80'},
          {'num_players': '2',
           'stage': 'showdown',
           'starting_pot_size': '80'}]}

The JSON file that gets produced has one of the above "hand" dictionaries per line, "dumped" into JSON format,
and ready for loading into MongoDB.
'''


# Parses "hdb" file from the IRC Poker Database http://poker.cs.ualberta.ca/irc_poker_database.html
import xlrd
import os
import csv
from tarfile import TarFile
import pprint
import re
import codecs
import json

# ENVIRONMENT VARIABLES -- CHANGE THESE TO FIT YOUR ENVIRONMENT
tgz_extract_directory = "/Users/davidsmith/Downloads/"
OUTFILE = tgz_extract_directory + "cprg_hands.json"
#

# Global variables
pot_cats = ["flop", "turn", "river", "showdown"]
deck = {'A': 'ace', 'K': 'king', 'Q': 'queen', 'J': 'jack', 'T': '10'}
suits = {'c': 'clubs', 's': 'spades', 'h': 'hearts', 'd': 'diamonds'}
bet_action_codes = {
            '-' : 'no action',
            'B' : 'blind bet',
            'f' : 'fold',
            'k' : 'check',
            'b' : 'bet',
            'c' : 'call',
            'r' : 'raise',
            'A' : 'all-in',
            'Q' : 'quits game',
            'K' : 'kicked from game'
            }
bet_action_cats = ["pre-flop", "flop", "turn", "river"]
folder_search_re = re.compile(r'\d{6}$', re.IGNORECASE)
tgz_search_re = re.compile(r'^\S*.\d{6}.tgz$', re.IGNORECASE)
valid_game_types = {"holdem", "holdem1", "holdem2", "holdem3", "holdemii", "holdempot", "nolimit", "tourney"}

def parse_hdb_file(hdb_file, hands, invalid_keys):
    
    try:
        split_filename = hdb_file.split("/")
        id_prefix = split_filename[-3] + "_" + split_filename[-2] + "_"
        with open(hdb_file, "r") as hdb:
            for line in hdb:
                hand = {}
                pot_data = []
                board_card_data = []  
                line_parts = line.strip("\n").split(" ")
                line_parts = [elem for elem in line_parts if elem != '']
                _id = id_prefix + line_parts[0]
                hand["_id"] = _id
                hand["game_type"] = split_filename[-3]
                hand["dealer"] = int(line_parts[1])
                hand["hand_num"] = int(line_parts[2])
                hand["num_players"] = int(line_parts[3])
                for lp in line_parts[4:8]:
                    pot_data.append(lp)
                for bcd in line_parts[8:]:
                    board_card_data.append(bcd)

                pots = []
                i = 0
                for p in pot_data:
                    pot = {}
                    pot["stage"] = pot_cats[i]
                    if len(p.split("/")) == 2:
                        pot["num_players"] = int(p.split("/")[0])
                        pot["size"] = int(p.split("/")[1])
                    else:
                        invalid_keys.add(_id)
                    pots.append(pot)
                    i = i + 1

                board = []
                for b in board_card_data:
                    board_card = {}
                    if b != "":
                        if board_card_data.index(b) + 1 <= 3:
                            board_card["stage"] = "flop"
                        elif board_card_data.index(b) + 1 == 4:
                            board_card["stage"] = "turn"
                        elif board_card_data.index(b) + 1 == 5:
                            board_card["stage"] = "river"
                        if b[0] in deck.keys():
                            board_card["value"] = deck[b[0]]
                        else:
                            board_card["value"] = b[0]
                        board_card["suit"] = suits[b[1]]
                        board.append(board_card)

                hand["pots"] = pots
                hand["board"] = board
                hands[_id] = hand
        hdb.close()
        return hands, id_prefix, invalid_keys
    
    except KeyError, e:
        invalid_keys.add(_id)
        hdb.close()
        return hands, id_prefix, invalid_keys
    

def parse_hroster_file(hroster_file, id_prefix, hands, invalid_keys):
    
    try:
        with open(hroster_file, "r") as hroster:
            for line in hroster:
                players = {}
                line_parts = line.strip("\n").split(" ")
                line_parts = [elem for elem in line_parts if elem != ''] 
                _id = id_prefix + line_parts[0]
                player_data = line_parts[2:]
                for p in player_data:
                    player = {}
                    player["username"] = p
                    players[p] = player
                if _id in hands:
                    hands[_id]["players"] = players
                else:
                    invalid_keys.add(_id)
        hroster.close()
        return hands, invalid_keys

    except KeyError, e:
        invalid_keys.add(_id)
        hroster.close()
        return hands, invalid_keys

    
def parse_pdb_file(pdb_file, id_prefix, hands, invalid_keys):
    
    try:
        username = pdb_file.split(".")[-1]
        with open(pdb_file, "r") as pdb:
            for line in pdb:
                line_parts = line.strip("\n").split(" ")
                line_parts = [elem for elem in line_parts if elem != '']

                _id = id_prefix + line_parts[1]
                position = line_parts[3]

                bet_actions = []
                i = 0
                for item in line_parts:
                    bet_action = {}
                    bet_action["actions"] = []
                    if line_parts.index(item) >=4 and line_parts.index(item) <= 7:
                        for b in item:
                            bet_action["actions"].append(bet_action_codes[b])
                        bet_action["stage"] = bet_action_cats[i]
                        bet_actions.append(bet_action)
                        i = i + 1
                bankroll, action, winnings = line_parts[8:11]

                player_cards = []
                if len(line_parts) == 13:
                    for item in line_parts[11:13]:
                        player_card = {}
                        if item[0] in deck.keys():
                            player_card["value"] = deck[item[0]]
                        else:
                            player_card["value"] = item[0]
                        player_card["suit"] = suits[item[1]]
                        player_cards.append(player_card)              

                if _id in hands: 
                    if _id not in invalid_keys:
                        if username in hands[_id]["players"]:
                            hands[_id]["players"][username]["bet_actions"] = bet_actions
                            hands[_id]["players"][username]["bankroll"] = int(bankroll)
                            hands[_id]["players"][username]["action"] = int(action)
                            hands[_id]["players"][username]["winnings"] = int(winnings)
                            hands[_id]["players"][username]["player_cards"] = player_cards
                            hands[_id]["players"][username]["position"] = int(position)
                        else:
                            invalid_keys.add(_id)
                else:
                    invalid_keys.add(_id)
        pdb.close()
        return hands, invalid_keys
    
    except IndexError, e:
        invalid_keys.add(_id)
        pdb.close()
        return hands, invalid_keys
    except KeyError, e:
        invalid_keys.add(_id)
        pdb.close()
        return hands, invalid_keys
    except ValueError, e:
        invalid_keys.add(_id)
        pdb.close()
        return hands, invalid_keys


def loop_pdb_files(pdb_file_directory, hands_col, id_prefix, invalid_keys):
    for root, dirs, files in os.walk(pdb_file_directory, topdown=False):
        for name in files:
            pdb_file = os.path.join(root, name)
            hs = parse_pdb_file(pdb_file, id_prefix, hands_col, invalid_keys)
    return hands_col, invalid_keys


def fix_players_list(hands_list):
    fixed_hands_list = []
    for h in hands_list:
        if "players" in h:
            players_list = h["players"].values()
            h["players"] = players_list
            fixed_hands_list.append(h)
    return fixed_hands_list


def loop_file_groups(file_groups):
    total_to_process = len(file_groups)
    i = 1
    running_total = 0
    for fg in file_groups:
        hands = {}
        hands_list = []
        invalid_keys = set()
        print "Processing " + fg + " (file group #" + str(i) + " of " + str(total_to_process) + ")"
        hdb_file = fg + "hdb"
        hroster_file = fg + "hroster"
        pdb_directory = fg + "pdb/"
        hands, idp, inv_keys = parse_hdb_file(hdb_file, hands, invalid_keys)
        hands, inv_keys = parse_hroster_file(hroster_file, idp, hands, inv_keys)
        hands, inv_keys = loop_pdb_files(pdb_directory, hands, idp, inv_keys)
        hands = {key: hands[key] for key in hands if key not in inv_keys}
        hands_list = fix_players_list(hands.values())
        append_hands_list_to_json_file(hands_list)
        print str(len(hands_list)) + " valid hands added to JSON file, " + str(len(inv_keys)) + " invalid hands"
        running_total = running_total + len(hands_list)
        print str(running_total) + " total hands added so far"
        print "Finished processing " + fg
        i = i + 1


def loop_tgz(extract_dir):
    file_groups = []
    for root, dirs, files in os.walk(tgz_extract_directory, topdown=False):
        for file in files:            
            tgz = tgz_search_re.search(file)
            if tgz:
                tgz_file = os.path.join(root, file)
                game_type = tgz_file.split(".")[-3].split("/")[-1]
                file_yearmonth = tgz_file.split(".")[-2]
                if game_type in valid_game_types:
                    print "Extracting " + tgz_file
                    tar = TarFile.open(tgz_file)
                    tar.extractall(extract_dir)
                    tar.close()
                    file_groups.append(tgz_extract_directory + game_type + "/" + file_yearmonth + "/")
                else:
                    print "Skipping " + tgz_file + " because it is for an invalid game type"
    return file_groups

                
def append_hands_list_to_json_file(hands_list):
    with codecs.open(OUTFILE, "a") as fo:
        for hand in hands_list:
            fo.write(json.dumps(hand) + "\n")
    fo.close()
    

file_groups = loop_tgz(tgz_extract_directory)
if os.path.isfile(OUTFILE): os.remove(OUTFILE)
loop_file_groups(file_groups)
print "All done!"


# Still to do 10/4/15:
# Download the tgz files directly from the Internet (http://poker.cs.ualberta.ca/IRCdata/) rather than by hand
# Out:
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199504.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199505.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199506.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199507.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199508.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199509.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199510.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199511.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199512.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199601.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199602.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199603.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199604.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199605.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199606.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199607.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199608.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199609.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199610.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199611.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199612.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199701.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199702.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199703.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199704.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199705.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199707.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199708.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199802.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199803.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199804.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199805.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199806.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199807.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199808.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199809.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199810.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199811.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199812.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199901.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199902.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199903.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199904.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199905.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199906.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199907.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199908.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199909.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199910.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199911.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.199912.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200001.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200002.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200003.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200004.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200005.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200006.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200007.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200008.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200009.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200010.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200011.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200012.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200102.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200103.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200104.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200105.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200106.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200107.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200108.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200109.tgz
# Extracting /Users/davidsmith/Downloads/cprg tgz/holdem.200110.tgz
# Processing /Users/davidsmith/Downloads/holdem/199504/ (file group #1 of 72)
# 27541 valid hands added to JSON file, 0 invalid hands
# 27541 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199504/
# Processing /Users/davidsmith/Downloads/holdem/199505/ (file group #2 of 72)
# 31627 valid hands added to JSON file, 0 invalid hands
# 59168 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199505/
# Processing /Users/davidsmith/Downloads/holdem/199506/ (file group #3 of 72)
# 26531 valid hands added to JSON file, 0 invalid hands
# 85699 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199506/
# Processing /Users/davidsmith/Downloads/holdem/199507/ (file group #4 of 72)
# 23116 valid hands added to JSON file, 0 invalid hands
# 108815 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199507/
# Processing /Users/davidsmith/Downloads/holdem/199508/ (file group #5 of 72)
# 23113 valid hands added to JSON file, 0 invalid hands
# 131928 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199508/
# Processing /Users/davidsmith/Downloads/holdem/199509/ (file group #6 of 72)
# 33222 valid hands added to JSON file, 0 invalid hands
# 165150 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199509/
# Processing /Users/davidsmith/Downloads/holdem/199510/ (file group #7 of 72)
# 39834 valid hands added to JSON file, 0 invalid hands
# 204984 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199510/
# Processing /Users/davidsmith/Downloads/holdem/199511/ (file group #8 of 72)
# 33772 valid hands added to JSON file, 0 invalid hands
# 238756 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199511/
# Processing /Users/davidsmith/Downloads/holdem/199512/ (file group #9 of 72)
# 38853 valid hands added to JSON file, 0 invalid hands
# 277609 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199512/
# Processing /Users/davidsmith/Downloads/holdem/199601/ (file group #10 of 72)
# 36222 valid hands added to JSON file, 0 invalid hands
# 313831 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199601/
# Processing /Users/davidsmith/Downloads/holdem/199602/ (file group #11 of 72)
# 28147 valid hands added to JSON file, 0 invalid hands
# 341978 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199602/
# Processing /Users/davidsmith/Downloads/holdem/199603/ (file group #12 of 72)
# 33497 valid hands added to JSON file, 0 invalid hands
# 375475 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199603/
# Processing /Users/davidsmith/Downloads/holdem/199604/ (file group #13 of 72)
# 34619 valid hands added to JSON file, 0 invalid hands
# 410094 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199604/
# Processing /Users/davidsmith/Downloads/holdem/199605/ (file group #14 of 72)
# 32496 valid hands added to JSON file, 0 invalid hands
# 442590 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199605/
# Processing /Users/davidsmith/Downloads/holdem/199606/ (file group #15 of 72)
# 30587 valid hands added to JSON file, 0 invalid hands
# 473177 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199606/
# Processing /Users/davidsmith/Downloads/holdem/199607/ (file group #16 of 72)
# 34603 valid hands added to JSON file, 0 invalid hands
# 507780 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199607/
# Processing /Users/davidsmith/Downloads/holdem/199608/ (file group #17 of 72)
# 23485 valid hands added to JSON file, 0 invalid hands
# 531265 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199608/
# Processing /Users/davidsmith/Downloads/holdem/199609/ (file group #18 of 72)
# 18588 valid hands added to JSON file, 0 invalid hands
# 549853 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199609/
# Processing /Users/davidsmith/Downloads/holdem/199610/ (file group #19 of 72)
# 34122 valid hands added to JSON file, 0 invalid hands
# 583975 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199610/
# Processing /Users/davidsmith/Downloads/holdem/199611/ (file group #20 of 72)
# 42499 valid hands added to JSON file, 0 invalid hands
# 626474 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199611/
# Processing /Users/davidsmith/Downloads/holdem/199612/ (file group #21 of 72)
# 38313 valid hands added to JSON file, 0 invalid hands
# 664787 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199612/
# Processing /Users/davidsmith/Downloads/holdem/199701/ (file group #22 of 72)
# 40414 valid hands added to JSON file, 0 invalid hands
# 705201 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199701/
# Processing /Users/davidsmith/Downloads/holdem/199702/ (file group #23 of 72)
# 38164 valid hands added to JSON file, 0 invalid hands
# 743365 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199702/
# Processing /Users/davidsmith/Downloads/holdem/199703/ (file group #24 of 72)
# 44479 valid hands added to JSON file, 0 invalid hands
# 787844 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199703/
# Processing /Users/davidsmith/Downloads/holdem/199704/ (file group #25 of 72)
# 31062 valid hands added to JSON file, 0 invalid hands
# 818906 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199704/
# Processing /Users/davidsmith/Downloads/holdem/199705/ (file group #26 of 72)
# 36749 valid hands added to JSON file, 4 invalid hands
# 855655 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199705/
# Processing /Users/davidsmith/Downloads/holdem/199707/ (file group #27 of 72)
# 13170 valid hands added to JSON file, 3 invalid hands
# 868825 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199707/
# Processing /Users/davidsmith/Downloads/holdem/199708/ (file group #28 of 72)
# 8670 valid hands added to JSON file, 0 invalid hands
# 877495 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199708/
# Processing /Users/davidsmith/Downloads/holdem/199802/ (file group #29 of 72)
# 32721 valid hands added to JSON file, 0 invalid hands
# 910216 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199802/
# Processing /Users/davidsmith/Downloads/holdem/199803/ (file group #30 of 72)
# 51221 valid hands added to JSON file, 0 invalid hands
# 961437 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199803/
# Processing /Users/davidsmith/Downloads/holdem/199804/ (file group #31 of 72)
# 44141 valid hands added to JSON file, 0 invalid hands
# 1005578 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199804/
# Processing /Users/davidsmith/Downloads/holdem/199805/ (file group #32 of 72)
# 51026 valid hands added to JSON file, 0 invalid hands
# 1056604 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199805/
# Processing /Users/davidsmith/Downloads/holdem/199806/ (file group #33 of 72)
# 43558 valid hands added to JSON file, 8095 invalid hands
# 1100162 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199806/
# Processing /Users/davidsmith/Downloads/holdem/199807/ (file group #34 of 72)
# 58669 valid hands added to JSON file, 0 invalid hands
# 1158831 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199807/
# Processing /Users/davidsmith/Downloads/holdem/199808/ (file group #35 of 72)
# 51984 valid hands added to JSON file, 0 invalid hands
# 1210815 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199808/
# Processing /Users/davidsmith/Downloads/holdem/199809/ (file group #36 of 72)
# 40791 valid hands added to JSON file, 0 invalid hands
# 1251606 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199809/
# Processing /Users/davidsmith/Downloads/holdem/199810/ (file group #37 of 72)
# 44864 valid hands added to JSON file, 0 invalid hands
# 1296470 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199810/
# Processing /Users/davidsmith/Downloads/holdem/199811/ (file group #38 of 72)
# 432 valid hands added to JSON file, 38316 invalid hands
# 1296902 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199811/
# Processing /Users/davidsmith/Downloads/holdem/199812/ (file group #39 of 72)
# 38241 valid hands added to JSON file, 3 invalid hands
# 1335143 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199812/
# Processing /Users/davidsmith/Downloads/holdem/199901/ (file group #40 of 72)
# 38501 valid hands added to JSON file, 3 invalid hands
# 1373644 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199901/
# Processing /Users/davidsmith/Downloads/holdem/199902/ (file group #41 of 72)
# 33439 valid hands added to JSON file, 3 invalid hands
# 1407083 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199902/
# Processing /Users/davidsmith/Downloads/holdem/199903/ (file group #42 of 72)
# 36321 valid hands added to JSON file, 31 invalid hands
# 1443404 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199903/
# Processing /Users/davidsmith/Downloads/holdem/199904/ (file group #43 of 72)
# 36575 valid hands added to JSON file, 69 invalid hands
# 1479979 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199904/
# Processing /Users/davidsmith/Downloads/holdem/199905/ (file group #44 of 72)
# 50277 valid hands added to JSON file, 29 invalid hands
# 1530256 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199905/
# Processing /Users/davidsmith/Downloads/holdem/199906/ (file group #45 of 72)
# 39718 valid hands added to JSON file, 4 invalid hands
# 1569974 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199906/
# Processing /Users/davidsmith/Downloads/holdem/199907/ (file group #46 of 72)
# 41601 valid hands added to JSON file, 0 invalid hands
# 1611575 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199907/
# Processing /Users/davidsmith/Downloads/holdem/199908/ (file group #47 of 72)
# 44229 valid hands added to JSON file, 1 invalid hands
# 1655804 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199908/
# Processing /Users/davidsmith/Downloads/holdem/199909/ (file group #48 of 72)
# 40993 valid hands added to JSON file, 4 invalid hands
# 1696797 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199909/
# Processing /Users/davidsmith/Downloads/holdem/199910/ (file group #49 of 72)
# 43993 valid hands added to JSON file, 0 invalid hands
# 1740790 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199910/
# Processing /Users/davidsmith/Downloads/holdem/199911/ (file group #50 of 72)
# 42745 valid hands added to JSON file, 2 invalid hands
# 1783535 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199911/
# Processing /Users/davidsmith/Downloads/holdem/199912/ (file group #51 of 72)
# 42794 valid hands added to JSON file, 367 invalid hands
# 1826329 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/199912/
# Processing /Users/davidsmith/Downloads/holdem/200001/ (file group #52 of 72)
# 35019 valid hands added to JSON file, 0 invalid hands
# 1861348 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200001/
# Processing /Users/davidsmith/Downloads/holdem/200002/ (file group #53 of 72)
# 40537 valid hands added to JSON file, 0 invalid hands
# 1901885 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200002/
# Processing /Users/davidsmith/Downloads/holdem/200003/ (file group #54 of 72)
# 43930 valid hands added to JSON file, 0 invalid hands
# 1945815 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200003/
# Processing /Users/davidsmith/Downloads/holdem/200004/ (file group #55 of 72)
# 40575 valid hands added to JSON file, 20 invalid hands
# 1986390 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200004/
# Processing /Users/davidsmith/Downloads/holdem/200005/ (file group #56 of 72)
# 38382 valid hands added to JSON file, 1 invalid hands
# 2024772 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200005/
# Processing /Users/davidsmith/Downloads/holdem/200006/ (file group #57 of 72)
# 40981 valid hands added to JSON file, 0 invalid hands
# 2065753 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200006/
# Processing /Users/davidsmith/Downloads/holdem/200007/ (file group #58 of 72)
# 46727 valid hands added to JSON file, 0 invalid hands
# 2112480 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200007/
# Processing /Users/davidsmith/Downloads/holdem/200008/ (file group #59 of 72)
# 46847 valid hands added to JSON file, 0 invalid hands
# 2159327 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200008/
# Processing /Users/davidsmith/Downloads/holdem/200009/ (file group #60 of 72)
# 40716 valid hands added to JSON file, 0 invalid hands
# 2200043 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200009/
# Processing /Users/davidsmith/Downloads/holdem/200010/ (file group #61 of 72)
# 37502 valid hands added to JSON file, 0 invalid hands
# 2237545 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200010/
# Processing /Users/davidsmith/Downloads/holdem/200011/ (file group #62 of 72)
# 37639 valid hands added to JSON file, 0 invalid hands
# 2275184 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200011/
# Processing /Users/davidsmith/Downloads/holdem/200012/ (file group #63 of 72)
# 17854 valid hands added to JSON file, 0 invalid hands
# 2293038 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200012/
# Processing /Users/davidsmith/Downloads/holdem/200102/ (file group #64 of 72)
# 24827 valid hands added to JSON file, 0 invalid hands
# 2317865 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200102/
# Processing /Users/davidsmith/Downloads/holdem/200103/ (file group #65 of 72)
# 36525 valid hands added to JSON file, 0 invalid hands
# 2354390 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200103/
# Processing /Users/davidsmith/Downloads/holdem/200104/ (file group #66 of 72)
# 32102 valid hands added to JSON file, 8155 invalid hands
# 2386492 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200104/
# Processing /Users/davidsmith/Downloads/holdem/200105/ (file group #67 of 72)
# 39046 valid hands added to JSON file, 0 invalid hands
# 2425538 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200105/
# Processing /Users/davidsmith/Downloads/holdem/200106/ (file group #68 of 72)
# 39026 valid hands added to JSON file, 0 invalid hands
# 2464564 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200106/
# Processing /Users/davidsmith/Downloads/holdem/200107/ (file group #69 of 72)
# 43592 valid hands added to JSON file, 0 invalid hands
# 2508156 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200107/
# Processing /Users/davidsmith/Downloads/holdem/200108/ (file group #70 of 72)
# 39611 valid hands added to JSON file, 0 invalid hands
# 2547767 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200108/
# Processing /Users/davidsmith/Downloads/holdem/200109/ (file group #71 of 72)
# 46049 valid hands added to JSON file, 0 invalid hands
# 2593816 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200109/
# Processing /Users/davidsmith/Downloads/holdem/200110/ (file group #72 of 72)
# 36701 valid hands added to JSON file, 0 invalid hands
# 2630517 total hands added so far
# Finished processing /Users/davidsmith/Downloads/holdem/200110/
# All done!
