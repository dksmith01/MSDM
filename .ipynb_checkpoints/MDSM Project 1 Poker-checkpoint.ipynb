# %% [markdown]
# # Project 1: Poker Data
# ### September 27, 2015
#
# Insert narrative and some instructions here.

# %%
# Parses "hdb" file from the IRC Poker Database http://poker.cs.ualberta.ca/irc_poker_database.html
import xlrd
import os
import csv
from zipfile import ZipFile
import pprint
import re

download_directory = "/Users/davidsmith/Downloads/"
#hdb_file = download_directory + "nolimit/199505/hdb"
#hroster_file = download_directory + "nolimit/199505/hroster"
#pdb_file = download_directory + "nolimit/199505/pdb/pdb.ShoelessJ"
#pdf_directory = download_directory + "/nolimit/199505/pdb/"
outfile = download_directory + "hands_output.txt"

#def open_zip(datafile):
#    with ZipFile('{0}.zip'.format(datafile), 'r') as myzip:
#        myzip.extractall()

# Global variables
pot_cats = ["flop", "turn", "river", "showdown"]
deck = {'A': 'ace', 'K': 'king', 'Q': 'queen', 'J': 'jack', 'T': '10'}
suits = {'c': 'clubs', 's': 'spades', 'h': 'hearts', 'd': 'diamonds'}
bet_action_codes = {
            '-' : 'no action',
            'B' : 'blind bet',
            'f' : 'fold',
            'k' : 'check',
            'b' : 'bet',
            'c' : 'call',
            'r' : 'raise',
            'A' : 'all-in',
            'Q' : 'quits game',
            'K' : 'kicked from game'
            }
bet_action_cats = ["pre-flop", "flop", "turn", "river"]
folder_search_re = re.compile(r'\d{6}$', re.IGNORECASE)


def parse_hdb_file(hdb_file, hands):
    
    split_filename = hdb_file.split("/")
    id_prefix = split_filename[-3] + "_" + split_filename[-2] + "_"
    with open(hdb_file, "r") as hdb:
        for line in hdb:
            hand = {}
            pot_data = []
            board_card_data = []  
            _id = id_prefix + line[:9]
            hand["_id"] = _id
            hand["game_type"] = split_filename[-3]
            hand["dealer"] = line[10:13].strip()
            hand["hand_num"] = line[14:19].strip()
            hand["num_players"] = line[20:22].strip()
            pot_data.append(line[23:31].strip())
            pot_data.append(line[31:39].strip())
            pot_data.append(line[39:48].strip())
            pot_data.append(line[48:57].strip())
            board_card_data.append(line[58:60].strip().strip("\n"))
            board_card_data.append(line[61:63].strip().strip("\n"))
            board_card_data.append(line[64:66].strip().strip("\n"))
            board_card_data.append(line[67:69].strip().strip("\n"))
            board_card_data.append(line[70:72].strip().strip("\n"))
            
            pots = []
            i = 0
            for p in pot_data:
                pot = {}
                pot["stage"] = pot_cats[i]
                pot["num_players"] = p.split("/")[0]
                pot["starting_pot_size"] = p.split("/")[1]
                pots.append(pot)
                i = i + 1
                
            board = []
            for b in board_card_data:
                board_card = {}
                if b != "":
                    if board_card_data.index(b) + 1 <= 3:
                        board_card["stage"] = "flop"
                    elif board_card_data.index(b) + 1 == 4:
                        board_card["stage"] = "turn"
                    elif board_card_data.index(b) + 1 == 5:
                        board_card["stage"] = "river"
                    if b[0] in deck.keys():
                        board_card["value"] = deck[b[0]]
                    else:
                        board_card["value"] = b[0]
                    board_card["suit"] = suits[b[1]]
                    board.append(board_card)
                
            hand["pots"] = pots
            hand["board"] = board
            hands[_id] = hand
    hdb.close()
    return hands, id_prefix


def parse_hroster_file(hroster_file, id_prefix, hands):
    
    with open(hroster_file, "r") as hroster:
        for line in hroster:
            players = {}
            _id = id_prefix + line[:9]
            player_data = line[13:].strip("\n").split(" ")
            for p in player_data:
                player = {}
                player["username"] = p
                players[p] = player
            hands[_id]["players"] = players
    hroster.close()
    return hands

    
def parse_pdb_file(pdb_file, id_prefix, hands):
    
    username = pdb_file.split(".")[-1]
    with open(pdb_file, "r") as pdb:
        for line in pdb:
            _id = id_prefix + line[10:19]
            position = line[23:25].strip(" ")
            bet_action_rounds = line[26:47].split(" ")
            bet_action_rounds = [elem for elem in bet_action_rounds if elem != '']
            
            rest_of_line = line[26:].strip("\n").split(" ")
            rest_of_line = [elem for elem in rest_of_line if elem != '']
        
            bet_actions = []
            i = 0
            for item in rest_of_line:
                bet_action = {}
                bet_action["actions"] = []
                if rest_of_line.index(item) <= 3:
                    for b in item:
                        bet_action["actions"].append(bet_action_codes[b])
                    bet_action["stage"] = bet_action_cats[i]
                    bet_actions.append(bet_action)
                    i = i + 1
            bankroll, action, winnings = rest_of_line[4:7]
            player_cards = []
            if len(rest_of_line) == 9:
                for item in rest_of_line[7:9]:
                    player_card = {}
                    if item[0] in deck.keys():
                        player_card["value"] = deck[item[0]]
                    else:
                        player_card["value"] = item[0]
                    player_card["suit"] = suits[item[1]]
                    player_cards.append(player_card)                    
            hands[_id]["players"][username]["bet_actions"] = bet_actions
            hands[_id]["players"][username]["bankroll"] = int(bankroll)
            hands[_id]["players"][username]["action"] = int(action)
            hands[_id]["players"][username]["winnings"] = int(winnings)
            hands[_id]["players"][username]["player_cards"] = player_cards
            hands[_id]["players"][username]["position"] = int(position)
    pdb.close()
    return hands



def loop_pdb_files(pdb_file_directory, hands_col, id_prefix):
    for root, dirs, files in os.walk(pdb_file_directory, topdown=False):
        for name in files:
            pdb_file = os.path.join(root, name)
            print "Processing " + pdb_file + "..."
            hs = parse_pdb_file(pdb_file, id_prefix, hands_col)
    print "...Finished processing PDB files."
    return hands_col


def loop_file_groups():
    hands = {}
    hands_list = []
    for root, dirs, files in os.walk(download_directory, topdown=False):
        d = folder_search_re.search(root)
        if d:
            hdb_file = root + "/" + "hdb"
            print "Processing " + hdb_file + "..."
            hroster_file = root + "/" + "hroster"
            print "Processing " + hroster_file + "..."
            pdb_directory = root + "/" + "pdb/"
            print "Processing " + pdb_directory + "..."
            hands, idp = parse_hdb_file(hdb_file, hands)
            hands = parse_hroster_file(hroster_file, idp, hands)
            hands = loop_pdb_files(pdb_directory, hands, idp)
    hands_list = hands.values()
    return hands_list
            
    
hnds = loop_file_groups()
print len(hnds)

# Still to do 9/28/15:
# Download the files directly from the Internet (http://poker.cs.ualberta.ca/IRCdata/)
# DONE Loop through hdb and hroster files, DONE --> be sure to tack YearMonth onto front of timestamp field
# Loop through tgz files
# Change working directory?
# Out:
# Processing /Users/davidsmith/Downloads/holdem/199504/hdb...
# Processing /Users/davidsmith/Downloads/holdem/199504/hroster...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.[[...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.[]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.[]bot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.][...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^-__-^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^^^^^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^^^^^^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^awhyde...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^jc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^jcc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^Tony...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^why...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.^will...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._-_-_-_-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._Don...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._jc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._jcc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._O_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._why...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb._will...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.`...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.aaron...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ab0...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ACC...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ace_high...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ACESUP...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.achamber...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.achterbe...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.action...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.AhSo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.aida...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ajc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Akitas...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.aksum...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.AlBundy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.alfalfa...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.alfisha...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.allinboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.althea...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ams...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.an_idiot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.any2cnwin...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.AOL_D00D...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.AOL_GRUU...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.AOLGOOROO...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.apack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Arby...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.argh...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.argh^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.augie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.awhyde...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bad_beat...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.badbeat...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.baguette...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Beatle...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.beauzeau...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BeesiTsu...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BeesiTzu...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bellyache...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bharat...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bharat1...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Bigd...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BigSlick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BillyB...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bjl^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.blah...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bluffer...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bluftru...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bntyhntr...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Bob...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bobk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BorgAss...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Borgbug...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BorgChump...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Borgfish...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Borker...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bozombie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bp...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.brando...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.brec...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.brillo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bt...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Bullshit...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bunghole...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.BunnyKill...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Buz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Buzman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.bw...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.callbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.capbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.cardly...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.chale...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Champ...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.champion...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.chilcott...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.circle...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.cjl...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.clarko...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.clinton...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.cobain...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.CockSuck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.coconut...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Coltrane...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.comet...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.comet2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.COMPUSRVE...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.conrad...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.cooder...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Cornholio...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.cptdag...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.CuntWater...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Curt...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Cyrax...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.D...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.d0h...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.d_c...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.d_h...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.damnit...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Dan_G...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Danox...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.DanSal...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.darse...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.daveh...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.DavidT...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dbarnett...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.deadhead...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.derek...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dEthAngEl...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.die_puke...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dingle...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dj...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.DM...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.doc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.doc___...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.doc_doc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Don...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Don2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Don_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Donkey...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Dr_Devo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.drr...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.DSklansky...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dtg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dtm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.duggan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.DumBitch...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.dwallace...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.EbolaEric...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.EdK...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.eek...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ElDave...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.elraiso...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Elvis...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.emily...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ender...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.enzo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.erb...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.erc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ericm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Ether...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.EWORLD...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FatSlob...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.feeder...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FilaEbola...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Filaman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.fireman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.fish...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FishBone...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.fishboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FogDucker...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot0...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot3...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot4...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot5...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot6...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot7...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot8...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.foldbot9...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.fooled...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.franzen...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Fuck_You...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FuckYou...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.FuckYUY...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Fuzzy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Gambler...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.geg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.GeneScott...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.GetBigd...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.gfish...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Giligan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.gjg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.gmh...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.godot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Goo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Gr^zz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.greg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Grimm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Griz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Grumpy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Guacamole...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.gunner...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.H...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.hawaiiboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.heh...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Hercules...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.HickDead...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.HiredGun...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.hitcher...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.hitcher2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.HKead...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.hmmm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.horseplay...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.HoundDog...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.i6900779...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.i_am_bad...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.I_Stink...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.IamDaBest...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Iceman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.idiot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.IdunnoY...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.IFR...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ign0re...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.igor...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.iguana...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.IMTHEBEST...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ircuser...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.irwin...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ISTINK...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.itkas...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jacko...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jackster...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JacobyO...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Jalapeno...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jamb0rg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jamboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JamesBond...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jane...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Jarman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jarthur...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jaxter...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jazbo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jazzy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JBeers...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jc-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jc^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jc_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[4]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[5]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[6]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[7]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[8]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc[9]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jcc_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JeffK...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jf0...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Jhaala...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jib...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Jime...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Jime1...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jims...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Joe101...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JohnC...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JohnDoe2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.johnr...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jpm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jrx...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JSB...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JustBloMe...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.justin...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.justin-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.justin^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.justin_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.justnuts...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jwebb...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.JWilner...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jzk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jzkbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jzksb...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.jzksucks...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.k^man...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Kai...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kaishar...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.KarenB...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Kevin...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.KHead...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kick0...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kick2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kick3...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kidZee...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kman...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kmunn...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kr...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.krock...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.kul...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.KungLao...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Kurtz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.l...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.LarryC...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Lassie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.later...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.lcoltuse...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.lemur...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.leo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Lev...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.licker...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.lilwing...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Live_1...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Liver...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.logan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.LOSER...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.luckbox...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.m_e...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mac...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.magic...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.magick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.majic...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.majick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.majik...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Malmuth...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Maniac...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Maniac[1]...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mAniAcbOy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mark...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Matilda...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Max...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mazhik...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mbn...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mbn3...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mbuck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mescalito...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mew...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mew7...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MikeCaro...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.miyake...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MMalmuth...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Money...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MOost...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Mr^Happy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Mr_Happy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mrC...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MrHyde...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MrJenkins...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.mrPink...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MrX...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MucusPig...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.MucusP{ig...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.munch...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.murph...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Nater...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.neoncap...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.new...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.new_nick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.NICE...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.nick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Nova...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.npc...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.NumberOne...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.oejack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.offal...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ohjack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.OldMan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Omri...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Onions...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Orgg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.p_call...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pablo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.PapaLuck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.PapaSuck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pathetic...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.perdita...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.perfecto...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.perfecto3...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.perfecto4...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pete...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pg13...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Picard...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pliu...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.POed...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pogo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.PokerGuru...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.poolboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pops...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.prm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.PRODIJEE...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Prof...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.propdude...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.puke...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.puke1...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pukee...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pukescum...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.pumpuup...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Purity...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Q2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.quack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.queef...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Quick...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.qurterboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rabbitt...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rafe...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.RAMBO...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.RatedR...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Raybould...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rayzor...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rbmoore...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Restore...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.RFlagg...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Richard...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rimedio...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rkt...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rktbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rktbot2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Rob-F...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rocky...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rocky9...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rodney...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rolf...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.root...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Rosie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.rudeboy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.runner...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.RunStop...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sabu...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sagarbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sagerbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sagerbot2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sagerbot3...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sagerbot^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sakthi...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sakti...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.SaktiN...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.saktitkas...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sallen...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sally...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Schween...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.scooter...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.scrappy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sdfjh7234...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sexsux...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.shamrock...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Shazam...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Shazbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sheeva...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.shinner...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.shl...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.shmengie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ShoelessJ...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Shooter...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sippy...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sjack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sklansky...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Slacker...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.slandrum...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.slap...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Slime...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.slunk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sneezix...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Snerd...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.snot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.snowcone...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.spam...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.spam^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Spearmint...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Spike...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.SpooSuckr...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sport...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sports...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Stee...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.steve...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Stewie...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.StMroller...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.sts...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.suit...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Sure...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.swan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.T0NY...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.taki...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Taz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Test6...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.testbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.The...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tHe_bEst...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.The_Big_H...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.TheBest...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.TheHydra...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.TheKid...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.thunk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tightjack...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tim...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Timmy^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tmitchell...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tmp...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.TMX...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tomgo...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Tominator...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Tony...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tony^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Tony_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Topper...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tpm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.trm...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.troeger...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.TryIt...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tvp...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.tyde...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Tyler...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.UncleMeat...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Unyunz...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Vedder...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.VedderBot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.vedder{1}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.vegas...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.visionary...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Vomit...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.vs...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.vssRL...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.wademan...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.WCbot...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.WeakTight...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.welton...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.whiz2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.who...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Whoops...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.why...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.why-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.why^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.why_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.whyde...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.whyde^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.whyde_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.WildCard...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.WildCard2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.will...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.will-...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.will^...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.will_...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Winner777...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ws16...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.wsk...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.x^2-y^2...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.y_s...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Yabba-Dab...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ynotony...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.ynottony...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.You_Suck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.YouFuck...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.YouFucker...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Yui-Bin...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Zaphod...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Zar...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.zing...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.zingbust...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.zorak...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.Zorbaa...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{_____}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{____}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{___}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{__}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{_}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{maniac}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.{vedder}...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|-|-|-|...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|-|_|-|...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|__----...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|___---...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|maniac|...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|Theris|...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|vedder|...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.|||||...
# Processing /Users/davidsmith/Downloads/holdem/199504/pdb/pdb.}{...
# ...Finished processing PDB files.
# Processing /Users/davidsmith/Downloads/nolimit/199505/hdb...
# Processing /Users/davidsmith/Downloads/nolimit/199505/hroster...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/pdb.deadhead...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/pdb.greg...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/pdb.jzkbot...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/pdb.ShoelessJ...
# Processing /Users/davidsmith/Downloads/nolimit/199505/pdb/pdb.tvp...
# ...Finished processing PDB files.
# 28268
